# %%
a = "swati gaikwad"
print(a)

print(a[0], a[-1])
print(a[0], a[12])
print(a[0], a[len(a)-1])
print(a[10-10] ,a[12])
print(a[12-12] ,a[-1])
print(a[-13] ,a[12])
print(a[-13] ,a[-1])
print(a[-5+8] ,a[11+1])
print(a[-13+13] ,a[11-(-1)])
print(a[-10-3] ,a[10-(-2)])
# Out:
# swati gaikwad
# s d
# s d
# s d
# s d
# s d
# s d
# s d
# t d
# s d
# s d
